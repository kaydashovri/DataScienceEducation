# %% [markdown]
# ### *BONUS. Markdown и GIT для создания портфолио

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# пример того, как писать код в маркдауне
#
# ``` python
# lst = [10,13,14,523]
# summa = sum(lst)
#
# ```

# %% [markdown]
# пример того как писать формулы.
# Пусть задано выражение
# $$a = b + s, \text{ где } a = 0$$

# %% [markdown]
# $\alpha$
# $\gamma$
# $\sigma$

# %% [markdown]
# $a^2$ —
# $b_{ij}$ —
# $w^{ij}_n$ —

# %% [markdown]
# $\frac{1+x}{n}$ —

# %% [markdown]
# *Ум* заостряется от *книг*, словно *меч*.
