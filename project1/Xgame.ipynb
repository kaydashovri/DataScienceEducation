# %% [markdown]
# # Игра угадай число

# %%
import numpy as np
from Xgame_v2 import random_predict
from Xgame_v2 import score_game 
from Xgame_v2 import game_core_v2
from Xgame_v2 import game_core_v3

# %% [markdown]
# ## Подход 1: Случайное угадывание

# %%
score_game(random_predict)
# Out:
# Ваш алгоритм угадывает число в среднем за: 100 попытки

# %% [markdown]
# ## Подход 2: Угадывание с коррекцией

# %%
score_game(game_core_v2)
# Out:
# Ваш алгоритм угадывает число в среднем за: 32 попытки

# %% [markdown]
# ## Подход 3: Угадывание через выборку среднего значения в диапозоне чисел.

# %%
score_game(game_core_v3)
# Out:
# Ваш алгоритм угадывает число в среднем за: 5 попытки
